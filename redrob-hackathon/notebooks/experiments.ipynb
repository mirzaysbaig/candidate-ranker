# %% [markdown]
# # Offline Experiments Notebook
#
# Use this notebook to explore candidate profiles, test sentence-transformers models, and adjust Sigmoid scaling constants.

# %%
import sys
import os
import pandas as pd
import numpy as np

# Add root project folder to sys.path
sys.path.append(os.path.abspath('..'))

# %%
# Load configurations
from src.utils.helpers import load_yaml_config, load_candidates_jsonl
config = load_yaml_config('../configs/config.yaml')
print(config)
